# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import os
import datetime

# %%
data = xr.open_dataset('D:/code/python/draw/ERA5_sm20percentile_05area_month678.nc')
ds   = data['area']
ds1  = xr.open_dataset('D:/code/python/draw/ECMWF_sm20percentile_05area_22.nc')
da1  = ds1['area']

# %%
# 画图  
#  设置画图字体的大小
plt.rcParams.update({'font.size': 15})
#  解决中文乱码问题
plt.rcParams['font.sans-serif'] = ['SimHei']
#  解决负号乱码问题
plt.rcParams['axes.unicode_minus'] = False
color = ['#B22222', '#FF0000', '#FA8072', '#FF6100', '#D2691E', '#ED9121', '#FFD700', '#E3CF57', '#6B8E23', '#228B22', '#32CD32', '#87CEEB', '#4169E1', '#8A2BE2' ]
#设置颜色
x  = np.arange(16)
y1 = np.array(ds)#连续
y2 = np.array(da1)#分段
fig, ax1 = plt.subplots(figsize=(20,7))
ax1.plot(x,y1, color='black', marker='o', label='径流2')
ax1.set_ylabel('Area_drought', color='red')
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_yticks(range(0,2))
for i in range(14):#将不同的数据绘制在同一张图上
    ds1  = xr.open_dataset('D:/code/python/draw/ECMWF_sm20percentile_05area_'+str(i+22)+'.nc')
    da1  = ds1['area']
    y2   = np.array(da1)
    ax2 = ax1.twinx()
    ax2.set_yticks(range(0,2))
    ax2 = ax1.twinx()
    ax2.plot ([i,i+1,i+2],y2, color= color[i], marker='o', label='实测径流')
    ax2.set_yticks(range(0,2))

# %%
l1 = os.listdir('D:/code/python/draw/')
l2 = [] #存放x轴变量
for i in range(14):
    l2.append(l1[i][21:23]+l1[i][28:30])

s =int(l2[1])
s
# Out:
# 523

# %%
ds1  = xr.open_dataset('D:/code/python/draw/ECMWF_sm20percentile_05area_22.nc')
da1
# Out:
# <xarray.DataArray 'area' (7day: 3)>
# array([0.3     , 0.220588, 0.485294], dtype=float32)
# Dimensions without coordinates: 7day
# Attributes:
#     7day:     1
